# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pip install Konlpy
# Out:
# Collecting Konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
# Requirement already satisfied: numpy>=1.6 in c:\users\alsgu\anaconda3\lib\site-packages (from Konlpy) (1.21.2)
# Collecting JPype1>=0.7.0
#   Using cached JPype1-1.3.0-cp38-cp38-win_amd64.whl (362 kB)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\alsgu\anaconda3\lib\site-packages (from Konlpy) (4.6.4)
# Installing collected packages: JPype1, Konlpy
# Successfully installed JPype1-1.3.0 Konlpy-0.6.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 형태소 분석기(Konlpy)

# %%
from konlpy.tag import Twitter

twitter = Twitter()

print(twitter.pos('빅데이터 수업 너무 재미있다.'))
# Out:
# C:\Users\alsgu\anaconda3\lib\site-packages\konlpy\tag\_okt.py:17: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# [('빅데이터', 'Noun'), ('수업', 'Noun'), ('너무', 'Adverb'), ('재미있다', 'Adjective'), ('.', 'Punctuation')]

# %%
twitter = Twitter()

print(twitter.pos('빅데이터수업교수님너무좋으시다.'))
# Out:
# [('빅데이터', 'Noun'), ('수업', 'Noun'), ('교수', 'Noun'), ('님', 'Suffix'), ('너무', 'Adverb'), ('좋으시다', 'Adjective'), ('.', 'Punctuation')]
# C:\Users\alsgu\anaconda3\lib\site-packages\konlpy\tag\_okt.py:17: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
print(twitter.pos('아버지가방에들어가신다.'))
# Out:
# [('아버지', 'Noun'), ('가방', 'Noun'), ('에', 'Josa'), ('들어가신다', 'Verb'), ('.', 'Punctuation')]

# %%
print(twitter.pos('아버지가 방에 들어가신다.'))
# Out:
# [('아버지', 'Noun'), ('가', 'Josa'), ('방', 'Noun'), ('에', 'Josa'), ('들어가신다', 'Verb'), ('.', 'Punctuation')]

# %% [markdown]
# ## 웹 텍스트 데이터의 이해

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
